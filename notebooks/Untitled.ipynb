# %%
import pandas as pd
from pathlib import Path

# %%
fname = 'VJ_resize_LBP_2020-08-02_00-58.pickle'
df = pd.read_pickle(Path('..', 'Data', 'Processados', 'Resultados', fname))

df.head()
# Out:
#                                Preprocessamento  Acuracia Classificador  \
# 0  Data/features/VJ_resize_LBP/100_100/r_1_n_12  0.515447           SVM
# 0  Data/features/VJ_resize_LBP/100_100/r_1_n_12  0.552278           SVM
# 0  Data/features/VJ_resize_LBP/100_100/r_1_n_12  0.550460           SVM
# 0  Data/features/VJ_resize_LBP/100_100/r_1_n_12  0.552278           SVM
# 0  Data/features/VJ_resize_LBP/100_100/r_1_n_12  0.519995           SVM
#
#                            Hyperparametros
# 0  {'C': 1, 'degree': 1, 'kernel': 'poly'}
# 0   {'C': 1, 'degree': 1, 'kernel': 'rbf'}
# 0  {'C': 1, 'degree': 2, 'kernel': 'poly'}
# 0   {'C': 1, 'degree': 2, 'kernel': 'rbf'}
# 0  {'C': 1, 'degree': 3, 'kernel': 'poly'}

# %%
df.Acuracia.max()
# Out:
# 0.5981824782877528

# %%
df.sort_values(by='Acuracia', ascending=False)
# Out:
#                                 Preprocessamento  Acuracia Classificador  \
# 0    Data/features/VJ_resize_LBP/100_100/r_3_n_8  0.598182           SVM
# 0     Data/features/VJ_resize_LBP/64_128/r_2_n_8  0.597723           SVM
# 0     Data/features/VJ_resize_LBP/32_64/r_3_n_24  0.597266           SVM
# 0     Data/features/VJ_resize_LBP/64_128/r_3_n_8  0.596371           SVM
# 0   Data/features/VJ_resize_LBP/100_100/r_3_n_24  0.595906           SVM
# ..                                           ...       ...           ...
# 0     Data/features/VJ_resize_LBP/64_128/r_3_n_8  0.483185           SVM
# 0    Data/features/VJ_resize_LBP/64_128/r_3_n_24  0.481824           SVM
# 0    Data/features/VJ_resize_LBP/64_128/r_2_n_24  0.480456           SVM
# 0    Data/features/VJ_resize_LBP/64_128/r_3_n_24  0.479097           SVM
# 0    Data/features/VJ_resize_LBP/64_128/r_2_n_24  0.479086           SVM
#
#                               Hyperparametros
# ...
